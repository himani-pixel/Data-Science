# %% [markdown]
# # <b>Loops in Python</b>
#
# Python has two main loops: for and while.

# %% [markdown]
# ## <b>1. For Loop</b>
#
# Used to iterate over sequences like lists, tuples, and strings."

# %%
fruits = ["apple", "banana", "cherry"]

for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# - Using `range()`

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %% [markdown]
# ## <b>2. While Loop
#
# Runs as long as a condition is True.

# %%
count = 0
while count < 3:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2

# %% [markdown]
# ## <b>3. Loop Control Statements</b>
# - break → Exits the loop.
# - continue → Skips to the next iteration.
# - pass → Does nothing (used as a placeholder).

# %%
for i in range(5):
    if i == 3:
        break  
    print(i)
# Out:
# 0
# 1
# 2
