# %% [markdown]
# # <b>String Formatting and f-strings<b>

# %% [markdown]
# ## String Formatting in Python
# String is arguably the most used immutable data types in Python. Python provides multiple ways to format strings, including the format() method and f-strings (introduced in Python 3.6).

# %% [markdown]
# 1. Using `format()`

# %%
name = "Himani"
age = 25
print("My name is {} and I am {} years old.".format(name, age))
# Out:
# My name is Himani and I am 25 years old.

# %% [markdown]
# #### Positional and Keyword Arguments

# %%
print("{0} is learning {1}".format("Himani", "Python"))  # Using positions
print("{name} is learning {language}".format(name="Himani", language="Python"))
# Out:
# Himani is learning Python
# Himani is learning Python

# %% [markdown]
# ## 2. Using f-Strings (Recommended)

# %%
name = "Himani"
age = 25
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Himani and I am 25 years old.

# %% [markdown]
# - Expressions Inside f-Strings

# %%
a = 5
b = 10
print(f"Sum of {a} and {b} is {a + b}")
# Out:
# Sum of 5 and 10 is 15

# %% [markdown]
# - Formatting Numbers

# %%
pi = 3.14159
print(f"Pi rounded to 2 decimal places: {pi:.2f}")
# Out:
# Pi rounded to 2 decimal places: 3.14

# %% [markdown]
# - Padding and Alignment

# %%
print(f"{'Python':<10}")  # Left-align
print(f"{'Python':>10}")  # Right-align
print(f"{'Python':^10}")  # Center-align
# Out:
# Python
#     Python
#   Python
