# %% [markdown]
# # <b>Taking input from the user</b>

# %% [markdown]
# Basic Usage

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name:  Himani
# Hello Himani

# %% [markdown]
# Type Conversion<br>
# You can always convert the string output of input() function to other supported data types

# %%
age = int(input("Enter your age: "))
price = float(input("Enter the price: "))
# Out:
# Enter your age:  19
# Enter the price:  23.50
