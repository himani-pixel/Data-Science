# %% [markdown]
# # Data Transformation
# Once your data is clean, the next step is to reshape, reformat, and reorder it as needed for analysis. Pandas gives you plenty of flexible tools to do this.

# %% [markdown]
# ## Sorting & Ranking
# ### Sort by Values

# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 1                    565   6.0
# 2                   2024   8.4
# 3                    431   5.6
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 9                    266   5.9
# 10                   201   6.1
# 11                   342   8.2

# %%
df.sort_values("Year")                   # Ascending sort
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# 2                   2024   8.4
# 1                    565   6.0
# 10                   201   6.1
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2
# 3                    431   5.6
# 9                    266   5.9
# 0                   1050   7.2

# %%
df.sort_values("Year", ascending=False)  # Descending
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 2           Aamir Khan                    Dangal  2016        Biography
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 3                    431   5.6
# 9                    266   5.9
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 1                    565   6.0
# 10                   201   6.1
# 2                   2024   8.4

# %%
d2 = df.sort_values(["Year", "IMDb"]).copy()

# %%
d2
# Out:
#                  Actor                      Film  Year            Genre  \
# 2           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# 2                   2024   8.4
# 1                    565   6.0
# 10                   201   6.1
# 4                    585   7.0
# 6                    180   7.5
# 5                    111   8.3
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2
# 3                    431   5.6
# 9                    266   5.9
# 0                   1050   7.2

# %% [markdown]
# ### Reset Index
# If you want the index to start from 0 and be sequential, you can reset it using reset_index()

# %%
d2.reset_index(drop=True , inplace = True) # Reset the index and drop the old index

# %%
d2
# Out:
#                  Actor                      Film  Year            Genre  \
# 0           Aamir Khan                    Dangal  2016        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2         Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 3        Ranveer Singh                 Padmaavat  2018       Historical
# 4        Rajkummar Rao                     Stree  2018    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6       Hrithik Roshan                       War  2019           Action
# 7         Akshay Kumar                Good Newwz  2019           Comedy
# 8        Vicky Kaushal  Uri: The Surgical Strike  2019           Action
# 9        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 10       Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 11      Shah Rukh Khan                   Pathaan  2023           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   2024   8.4
# 1                    565   6.0
# 2                    201   6.1
# 3                    585   7.0
# 4                    180   7.5
# 5                    111   8.3
# 6                    475   6.5
# 7                    318   7.0
# 8                    342   8.2
# 9                    431   5.6
# 10                   266   5.9
# 11                  1050   7.2

# %% [markdown]
# - The df.sort_index() function is used to sort the DataFrame based on its index values. If the index is not in a sequential order (e.g., you have dropped rows or performed other operations that change the index), you can use sort_index() to restore it to a sorted order

# %% [markdown]
# ## Ranking
# The .rank() function in pandas is used to assign ranks to numeric values in a column, like scores or points. By default, it gives the average rank to tied values, which can result in decimal numbers. For example, if two people share the top score, they both get a rank of 1.5. You can customize the ranking behavior using the method parameter. One useful option is method='dense', which assigns the same rank to ties but doesn’t leave gaps in the ranking sequence. This is helpful when you want a clean, consecutive ranking system without skips.

# %%
df["Rank"] = df["IMDb"].rank(ascending = False)                 # Default: average method

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb  Rank
# 0                   1050   7.2   5.0
# 1                    565   6.0  10.0
# 2                   2024   8.4   1.0
# 3                    431   5.6  12.0
# 4                    585   7.0   6.5
# 5                    111   8.3   2.0
# 6                    180   7.5   4.0
# 7                    475   6.5   8.0
# 8                    318   7.0   6.5
# 9                    266   5.9  11.0
# 10                   201   6.1   9.0
# 11                   342   8.2   3.0

# %%
df["Rank"] = df["IMDb"].rank(method="dense" , ascending = False)

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb  Rank
# 0                   1050   7.2   5.0
# 1                    565   6.0   9.0
# 2                   2024   8.4   1.0
# 3                    431   5.6  11.0
# 4                    585   7.0   6.0
# 5                    111   8.3   2.0
# 6                    180   7.5   4.0
# 7                    475   6.5   7.0
# 8                    318   7.0   6.0
# 9                    266   5.9  10.0
# 10                   201   6.1   8.0
# 11                   342   8.2   3.0

# %% [markdown]
#   ## Renaming Columns & Index

# %%
df.rename(columns={"BoxOffice(INR Crore)": "BoxOffice"}, inplace=True)

# %%
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice  IMDb  Rank
# 0        1050   7.2   5.0
# 1         565   6.0   9.0
# 2        2024   8.4   1.0
# 3         431   5.6  11.0
# 4         585   7.0   6.0
# 5         111   8.3   2.0
# 6         180   7.5   4.0
# 7         475   6.5   7.0
# 8         318   7.0   6.0
# 9         266   5.9  10.0
# 10        201   6.1   8.0
# 11        342   8.2   3.0

# %%
df.rename(index={0: "ActorName", 1: "IMDb_Rank"}, inplace=True)

# %%
df
# Out:
#                         Actor                      Film  Year  \
# ActorName      Shah Rukh Khan                   Pathaan  2023
# IMDb_Rank         Salman Khan           Tiger Zinda Hai  2017
# 2                  Aamir Khan                    Dangal  2016
# 3               Ranbir Kapoor                Brahmastra  2022
# 4               Ranveer Singh                 Padmaavat  2018
# 5          Ayushmann Khurrana                 Andhadhun  2018
# 6               Rajkummar Rao                     Stree  2018
# 7              Hrithik Roshan                       War  2019
# 8                Akshay Kumar                Good Newwz  2019
# 9               Kartik Aaryan         Bhool Bhulaiyaa 2  2022
# 10               Varun Dhawan     Badrinath Ki Dulhania  2017
# 11              Vicky Kaushal  Uri: The Surgical Strike  2019
#
#                      Genre  BoxOffice  IMDb  Rank
# ActorName           Action       1050   7.2   5.0
# IMDb_Rank           Action        565   6.0   9.0
# 2                Biography       2024   8.4   1.0
# 3                  Fantasy        431   5.6  11.0
# 4               Historical        585   7.0   6.0
# 5                 Thriller        111   8.3   2.0
# 6            Horror Comedy        180   7.5   4.0
# 7                   Action        475   6.5   7.0
# 8                   Comedy        318   7.0   6.0
# 9            Horror Comedy        266   5.9  10.0
# 10         Romantic Comedy        201   6.1   8.0
# 11                  Action        342   8.2   3.0
