# %% [markdown]
# #### Pandas is built on two main data structures:
#
# - Series → One-dimensional (like a single column in Excel)
# - DataFrame → Two-dimensional (like a full spreadsheet or SQL table)

# %% [markdown]
# ## Series — 1D Labeled Array
# A Series is like a list with labels (index)

# %%
import pandas as pd

# %%
s1 = pd.Series([78, 92, 65, 84, 71, 56])
print(s1)
type(s1)
# Out:
# 0    78
# 1    92
# 2    65
# 3    84
# 4    71
# 5    56
# dtype: int64
# pandas.core.series.Series

# %%
s2 = pd.Series([78, 92, 65, 84, 71, 56],["Himani" , "Shubham" , "Vaishanavi" , "Vaidehi" , "Tanvi" , "Mohit"])
print(s2)
type(s2)
# Out:
# Himani        78
# Shubham       92
# Vaishanavi    65
# Vaidehi       84
# Tanvi         71
# Mohit         56
# dtype: int64
# pandas.core.series.Series

# %% [markdown]
# ## DataFrame — 2D Labeled Table
# A DataFrame is like a dictionary of Series — multiple columns with labels.

# %%
data = {
    "Name" : ["Himani" , "Shubham" , "Vaishanavi" , "Vaidehi" , "Tanvi" , "Mohit"],
    "Marks" : [78, 92, 65, 84, 71, 56]
}
df = pd.DataFrame(data)
print(df)
# Out:
#          Name  Marks
# 0      Himani     78
# 1     Shubham     92
# 2  Vaishanavi     65
# 3     Vaidehi     84
# 4       Tanvi     71
# 5       Mohit     56

# %% [markdown]
# #### <i>Each column in a DataFrame is a Series.</i>

# %% [markdown]
# ### Index and Labels
# Every Series and DataFrame has an Index — it helps with:
#
# - Fast lookups
# - Aligning data
# - Merging & joining
# - Time series operations

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %% [markdown]
# ##### You can change them using:

# %%
df.columns = ["Name" ,"Age"]

# %%
print(df)
# Out:
#          Name  Age
# 0      Himani   78
# 1     Shubham   92
# 2  Vaishanavi   65
# 3     Vaidehi   84
# 4       Tanvi   71
# 5       Mohit   56

# %% [markdown]
# ### Summary
# - Series = 1D array with labels
# - DataFrame = 2D table with rows + columns
# - Both come with index and are the heart of Pandas
